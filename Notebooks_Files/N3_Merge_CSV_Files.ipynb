# %%
# read all files in a loop
# merge them in a single cell

import pandas as pd

# index: 0,1,2,3,4,...
# need to add more files? just add the file_names below
#  ./../Dataset_TweetIDsAndScores/
tweet_ids_files = ['./../Dataset1_TweetIDsAndScores/april1_april2.csv',
                   './../Dataset1_TweetIDsAndScores/april2_april3.csv',
                   './../Dataset1_TweetIDsAndScores/april3_april4.csv',
                   './../Dataset1_TweetIDsAndScores/april4_april5.csv',
                   './../Dataset1_TweetIDsAndScores/april5_april6.csv',
                   './../Dataset1_TweetIDsAndScores/april6_april7.csv',
                   './../Dataset1_TweetIDsAndScores/april7_april8.csv',
                   './../Dataset1_TweetIDsAndScores/april8_april9.csv',
                   './../Dataset1_TweetIDsAndScores/april9_april10.csv',
                   './../Dataset1_TweetIDsAndScores/april10_april11.csv',
                   './../Dataset1_TweetIDsAndScores/april11_april12.csv',
                   './../Dataset1_TweetIDsAndScores/april12_april13.csv',
                   './../Dataset1_TweetIDsAndScores/april13_april14.csv',
                   './../Dataset1_TweetIDsAndScores/april14_april15.csv',
                   './../Dataset1_TweetIDsAndScores/april15_april16.csv',
                  './../Dataset1_TweetIDsAndScores/april16_april17.csv',
                   './../Dataset1_TweetIDsAndScores/april17_april18.csv',
                   './../Dataset1_TweetIDsAndScores/april18_april19.csv',
                   './../Dataset1_TweetIDsAndScores/april19_april20.csv',
                   './../Dataset1_TweetIDsAndScores/april20_april21.csv',
                   './../Dataset1_TweetIDsAndScores/april21_april22.csv',
                   './../Dataset1_TweetIDsAndScores/april22_april23.csv',
                   './../Dataset1_TweetIDsAndScores/april23_april24.csv',
                   './../Dataset1_TweetIDsAndScores/april24_april25.csv',
                   './../Dataset1_TweetIDsAndScores/april25_april26.csv',
                  './../Dataset1_TweetIDsAndScores/april26_april27.csv',
                   './../Dataset1_TweetIDsAndScores/april27_april28.csv',
                   './../Dataset1_TweetIDsAndScores/april28_april29.csv',
                   './../Dataset1_TweetIDsAndScores/april29_april30.csv',
                   './../Dataset1_TweetIDsAndScores/april30_may1.csv',
                  './../Dataset1_TweetIDsAndScores/may1_may2.csv',
                   './../Dataset1_TweetIDsAndScores/may2_may3.csv',
                   './../Dataset1_TweetIDsAndScores/may3_may4.csv',
                   './../Dataset1_TweetIDsAndScores/may4_may5.csv',
                   './../Dataset1_TweetIDsAndScores/may5_may6.csv',
                    './../Dataset1_TweetIDsAndScores/may6_may7.csv',
                   './../Dataset1_TweetIDsAndScores/may7_may8.csv',
                   './../Dataset1_TweetIDsAndScores/may8_may9.csv',
                   './../Dataset1_TweetIDsAndScores/may9_may10.csv',
                   './../Dataset1_TweetIDsAndScores/may10_may11.csv',
                  './../Dataset1_TweetIDsAndScores/may11_may12.csv',
                  './../Dataset1_TweetIDsAndScores/may12_may13.csv',
                  './../Dataset1_TweetIDsAndScores/may13_may14.csv',
                  './../Dataset1_TweetIDsAndScores/may14_may15.csv',
                  './../Dataset1_TweetIDsAndScores/may15_may16.csv',
                  './../Dataset1_TweetIDsAndScores/may16_may17.csv',
                  './../Dataset1_TweetIDsAndScores/may17_may18.csv',
                  './../Dataset1_TweetIDsAndScores/may18_may19.csv',
                  './../Dataset1_TweetIDsAndScores/may19_may20.csv',
                  './../Dataset1_TweetIDsAndScores/may20_may21.csv',
                  './../Dataset1_TweetIDsAndScores/may21_may22.csv',
                  './../Dataset1_TweetIDsAndScores/may22_may23.csv',
                  './../Dataset1_TweetIDsAndScores/may23_may24.csv',
                  './../Dataset1_TweetIDsAndScores/may24_may25.csv',
                  './../Dataset1_TweetIDsAndScores/may25_may26.csv',
                  './../Dataset1_TweetIDsAndScores/may26_may27.csv',
                  './../Dataset1_TweetIDsAndScores/may27_may28.csv',
                  './../Dataset1_TweetIDsAndScores/may28_may29.csv',
                  './../Dataset1_TweetIDsAndScores/may29_may30.csv',
                  './../Dataset1_TweetIDsAndScores/may30_may31.csv',
                  './../Dataset1_TweetIDsAndScores/may31_june1.csv']

#./../Dataset4_MainTweetsFields
hydrated_files = ['./../Dataset4_MainTweetsFields/new_apr1-2.csv',
                  './../Dataset4_MainTweetsFields/new_apr2-3.csv',
                  './../Dataset4_MainTweetsFields/new_apr3-4.csv',
                  './../Dataset4_MainTweetsFields/new_apr4-5.csv',
                  './../Dataset4_MainTweetsFields/new_apr5-6.csv',
                  './../Dataset4_MainTweetsFields/new_apr6-7.csv',
                  './../Dataset4_MainTweetsFields/new_apr7-8.csv',
                  './../Dataset4_MainTweetsFields/new_apr8-9.csv',
                  './../Dataset4_MainTweetsFields/new_apr9-10.csv',
                  './../Dataset4_MainTweetsFields/new_apr10-11.csv',
                  './../Dataset4_MainTweetsFields/new_apr11-12.csv',
                  './../Dataset4_MainTweetsFields/new_apr12-13.csv',
                  './../Dataset4_MainTweetsFields/new_apr13-14.csv',
                  './../Dataset4_MainTweetsFields/new_apr14-15.csv',
                  './../Dataset4_MainTweetsFields/new_apr15-16.csv',
                 './../Dataset4_MainTweetsFields/new_apr16-17.csv',
                  './../Dataset4_MainTweetsFields/new_apr17-18.csv',
                  './../Dataset4_MainTweetsFields/new_apr18-19.csv',
                  './../Dataset4_MainTweetsFields/new_apr19-20.csv',
                  './../Dataset4_MainTweetsFields/new_apr20-21.csv',
                 './../Dataset4_MainTweetsFields/new_apr21-22.csv',
                  './../Dataset4_MainTweetsFields/new_apr22-23.csv',
                  './../Dataset4_MainTweetsFields/new_apr23-24.csv',
                  './../Dataset4_MainTweetsFields/new_apr24-25.csv',
                  './../Dataset4_MainTweetsFields/new_apr25-26.csv',
                 './../Dataset4_MainTweetsFields/new_apr26-27.csv',
                  './../Dataset4_MainTweetsFields/new_apr27-28.csv',
                  './../Dataset4_MainTweetsFields/new_apr28-29.csv',
                  './../Dataset4_MainTweetsFields/new_apr29-30.csv',
                  './../Dataset4_MainTweetsFields/new_apr30-may1.csv',
                 './../Dataset4_MainTweetsFields/new_may1-2.csv',
                  './../Dataset4_MainTweetsFields/new_may2-3.csv',
                  './../Dataset4_MainTweetsFields/new_may3-4.csv',
                  './../Dataset4_MainTweetsFields/new_may4-5.csv',
                  './../Dataset4_MainTweetsFields/new_may5-6.csv',
                   './../Dataset4_MainTweetsFields/new_may6-7.csv',
                  './../Dataset4_MainTweetsFields/new_may7-8.csv',
                  './../Dataset4_MainTweetsFields/new_may8-9.csv',
                  './../Dataset4_MainTweetsFields/new_may9-10.csv',
                  './../Dataset4_MainTweetsFields/new_may10-11.csv',
                 './../Dataset4_MainTweetsFields/new_may11-12.csv',
                 './../Dataset4_MainTweetsFields/new_may12-13.csv',
                 './../Dataset4_MainTweetsFields/new_may13-14.csv',
                 './../Dataset4_MainTweetsFields/new_may14-15.csv',
                 './../Dataset4_MainTweetsFields/new_may15-16.csv',
                                   './../Dataset4_MainTweetsFields/new_may16-17.csv',
                                   './../Dataset4_MainTweetsFields/new_may17-18.csv',
                                   './../Dataset4_MainTweetsFields/new_may18-19.csv',
                                   './../Dataset4_MainTweetsFields/new_may19-20.csv',
                                    './../Dataset4_MainTweetsFields/new_may20-21.csv',
                                  './../Dataset4_MainTweetsFields/new_may21-22.csv',
                                './../Dataset4_MainTweetsFields/new_may22-23.csv',
                              './../Dataset4_MainTweetsFields/new_may23-24.csv',
                              './../Dataset4_MainTweetsFields/new_may24-25.csv',
                                './../Dataset4_MainTweetsFields/new_may25-26.csv',
                                './../Dataset4_MainTweetsFields/new_may26-27.csv',
                                './../Dataset4_MainTweetsFields/new_may27-28.csv',
                                 './../Dataset4_MainTweetsFields/new_may28-29.csv',
                                 './../Dataset4_MainTweetsFields/new_may29-30.csv',
                                 './../Dataset4_MainTweetsFields/new_may30-31.csv',
                  './../Dataset4_MainTweetsFields/new_may31-june1.csv']
# march20_march21.csv: March 20, 2020 01:37 AM - March 21, 2020 09:25 AM
output_files = ['./../Dataset5_MainTweetsFieldsandScores/output-2020-04-01.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-02.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-03.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-04.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-05.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-06.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-07.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-08.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-09.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-10.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-11.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-12.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-13.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-14.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-15.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-16.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-17.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-18.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-19.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-20.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-04-21.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-22.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-23.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-24.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-25.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-04-26.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-27.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-28.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-29.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-04-30.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-05-01.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-05-02.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-05-03.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-05-04.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-05-05.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-05-06.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-05-07.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-05-08.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-05-09.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-05-10.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-05-11.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-05-12.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-05-13.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-05-14.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-05-15.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-05-16.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-05-17.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-05-18.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-05-19.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-05-20.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-05-21.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-05-22.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-05-23.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-05-24.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-05-25.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-05-26.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-05-27.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-05-28.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-05-29.csv',
               './../Dataset5_MainTweetsFieldsandScores/output-2020-05-30.csv',
                './../Dataset5_MainTweetsFieldsandScores/output-2020-05-31.csv']
            
    
    
for idx in range(len(tweet_ids_files)):
    left = pd.read_csv(tweet_ids_files[idx])    
    left.columns = ['Tweet ID','Sentiment Score']
    right = pd.read_csv(hydrated_files[idx]) 
    right.columns = ['Tweet ID', 'Long', 'Lat'] 
    
    outfile = pd.merge(left, right, how='inner', on='Tweet ID')    #keep the left file data
    outfile.to_csv(output_files[idx], index=False)        
    idx += 1
